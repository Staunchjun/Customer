# %%
import pandas as pd
import numpy as np
def delUnname0(df):
    df = df.drop('Unnamed: 0',axis=1)
    return df
def LoadData():
    pd.set_option('display.max_columns', 120)
    Customer_Flow = pd.read_csv("Customer_Flow.csv")
    Customer_Flow = delUnname0(Customer_Flow)
    Customer_Flow['data'] = pd.to_datetime(Customer_Flow['data'])
    return  Customer_Flow
def GenerateAllData(Customer_Flow):
    p_startt = pd.to_datetime("2016-11-01")
    p_endt = pd.to_datetime("2016-11-14")
    p_time = pd.date_range(start=p_startt, end=p_endt, freq='D')
    p_shop_id = range(1, 2001, 1)
    shopid = []
    p_t = []
    for shop_id in p_shop_id:
        for t in p_time:
            shopid.append(shop_id)
            p_t.append(t)
    predict = {'data': p_t, 'shop_id': shopid}
    predict = pd.DataFrame(predict)
    all_data = Customer_Flow.merge(predict, how='outer')
    return all_data

# %%
p_result = []
Customer_Flow = LoadData()
all_data = GenerateAllData(Customer_Flow)

# %%
p_result = []
for shop_id,eachShop in all_data.groupby(['shop_id']):
    eachShop.reset_index(inplace=True)
    eachShop.drop(['index'],inplace=True,axis=1)
    print 'computing....'
    result=[]
    result.append(shop_id)
    for x in range(len(eachShop)-1-13,len(eachShop)):
        eachline = eachShop.ix[x:x]
        fourteen = eachShop.ix[x-14:x-1]
        meanValue14 = fourteen['Num'].mean()
        eachline['Num'] = meanValue14
        result.append(meanValue14)
        eachShop.update(eachline) 
    p_result.append(result)     
    print shop_id,' prediction has finished!'
# Out:
# d:\python64\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# d:\python64\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# computing....
# 1.0  prediction has finished!
# computing....
# 2.0  prediction has finished!
# computing....
# 3.0  prediction has finished!
# computing....
# 4.0  prediction has finished!
# computing....
# 5.0  prediction has finished!
# computing....
# 6.0  prediction has finished!
# computing....
# 7.0  prediction has finished!
# computing....
# 8.0  prediction has finished!
# computing....
# 9.0  prediction has finished!
# computing....
# 10.0  prediction has finished!
# computing....
# 11.0  prediction has finished!
# computing....
# 12.0  prediction has finished!
# computing....
# 13.0  prediction has finished!
# computing....
# 14.0  prediction has finished!
# computing....
# 15.0  prediction has finished!
# computing....
# 16.0  prediction has finished!
# computing....
# 17.0  prediction has finished!
# computing....
# 18.0  prediction has finished!
# computing....
# 19.0  prediction has finished!
# computing....
# 20.0  prediction has finished!
# computing....
# 21.0  prediction has finished!
# computing....
# 22.0  prediction has finished!
# computing....
# 23.0  prediction has finished!
# computing....
# 24.0  prediction has finished!
# computing....
# 25.0  prediction has finished!
# computing....
# 26.0  prediction has finished!
# computing....
# 27.0  prediction has finished!
# computing....
# 28.0  prediction has finished!
# computing....
# 29.0  prediction has finished!
# computing....
# 30.0  prediction has finished!
# computing....
# 31.0  prediction has finished!
# computing....
# 32.0  prediction has finished!
# computing....
# 33.0  prediction has finished!
# computing....
# 34.0  prediction has finished!
# computing....
# 35.0  prediction has finished!
# computing....
# 36.0  prediction has finished!
# computing....
# 37.0  prediction has finished!
# computing....
# 38.0  prediction has finished!
# computing....
# 39.0  prediction has finished!
# computing....
# 40.0  prediction has finished!
# computing....
# 41.0  prediction has finished!
# computing....
# 42.0  prediction has finished!
# computing....
# 43.0  prediction has finished!
# computing....
# 44.0  prediction has finished!
# computing....
# 45.0  prediction has finished!
# computing....
# 46.0  prediction has finished!
# computing....
# 47.0  prediction has finished!
# computing....
# 48.0  prediction has finished!
# computing....
# 49.0  prediction has finished!
# computing....
# 50.0  prediction has finished!
# computing....
# 51.0  prediction has finished!
# computing....
# 52.0  prediction has finished!
# computing....
# 53.0  prediction has finished!
# computing....
# 54.0  prediction has finished!
# computing....
# 55.0  prediction has finished!
# computing....
# 56.0  prediction has finished!
# computing....
# 57.0  prediction has finished!
# computing....
# 58.0  prediction has finished!
# computing....
# 59.0  prediction has finished!
# computing....
# 60.0  prediction has finished!
# computing....
# 61.0  prediction has finished!
# computing....
# 62.0  prediction has finished!
# computing....
# 63.0  prediction has finished!
# computing....
# 64.0  prediction has finished!
# computing....
# 65.0  prediction has finished!
# computing....
# 66.0  prediction has finished!
# computing....
# 67.0  prediction has finished!
# computing....
# 68.0  prediction has finished!
# computing....
# 69.0  prediction has finished!
# computing....
# 70.0  prediction has finished!
# computing....
# 71.0  prediction has finished!
# computing....
# 72.0  prediction has finished!
# computing....
# 73.0  prediction has finished!
# computing....
# 74.0  prediction has finished!
# computing....
# 75.0  prediction has finished!
# computing....
# 76.0  prediction has finished!
# computing....
# 77.0  prediction has finished!
# computing....
# 78.0  prediction has finished!
# computing....
# 79.0  prediction has finished!
# computing....
# 80.0  prediction has finished!
# computing....
# 81.0  prediction has finished!
# computing....
# 82.0  prediction has finished!
# computing....
# 83.0  prediction has finished!
# computing....
# 84.0  prediction has finished!
# computing....
# 85.0  prediction has finished!
# computing....
# 86.0  prediction has finished!
# computing....
# 87.0  prediction has finished!
# computing....
# 88.0  prediction has finished!
# computing....
# 89.0  prediction has finished!
# computing....
# 90.0  prediction has finished!
# computing....
# 91.0  prediction has finished!
# computing....
# 92.0  prediction has finished!
# computing....
# 93.0  prediction has finished!
# computing....
# 94.0  prediction has finished!
# computing....
# 95.0  prediction has finished!
# computing....
# 96.0  prediction has finished!
# computing....
# 97.0  prediction has finished!
# computing....
# 98.0  prediction has finished!
# computing....
# 99.0  prediction has finished!
# computing....
# 100.0  prediction has finished!
# computing....
# 101.0  prediction has finished!
# computing....
# 102.0  prediction has finished!
# computing....

# %%
p_result = abs(pd.DataFrame(p_result).astype(int))
p_result.to_csv('LR.csv',header=False,index=False,encoding='utf-8')
